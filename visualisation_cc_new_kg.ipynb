# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
d = {'not found': [20, 7], 'found (not redirected)': [8,5], 'timeout': [1,2], 'error':[10,42], 'redirected':[61,44]}
df = pd.DataFrame(data=d, index=['new', 'old'])
df
# Out:
#      not found  found (not redirected)  timeout  error  redirected
# new         20                       8        1     10          61
# old          7                       5        2     42          44

# %%
d2 = {'not found': [24867, 39516], 'found (not redirected)': [52970,31609], 'error': [20631,25363], 'timeout':[1381,3081], 'Redirected until timeout':[1037,831],
'Redirected until not found':[6,0], 'Redirected until error':[5,0], 'Redirected until found':[169510,78617]}
cc = pd.DataFrame(data=d2, index=['old', 'new'])
cc

# %%
d2 = {'not found': [7645, 5091], 'found (not redirected)': [2865,13369], 'error': [8144,1110], 'timeout':[1155,403], 'Redirected until timeout':[5,779],
'Redirected until not found':[0,0], 'Redirected until error':[0,5], 'Redirected until found':[5471,42481]}
cc2 = pd.DataFrame(data=d2, index=['old', 'new'])
cc2
# Out:
#      not found  found (not redirected)  error  timeout  \
# old       7645                    2865   8144     1155
# new       5091                   13369   1110      403
#
#      Redirected until timeout  Redirected until not found  \
# old                         5                           0
# new                       779                           0
#
#      Redirected until error  Redirected until found
# old                       0                    5471
# new                       5                   42481

# %%
ax = cc2.T.plot.barh(figsize=(10,10))
ax.set_xlabel('#entities')
ax.set_title('CC(2)')
for container in ax.containers:
    ax.bar_label(container)

# %%
d3_9 = {'not found': [5226, 2951], 'found (not redirected)': [8999,4606], 'error': [4575,12018], 'timeout':[1004,411], 'Redirected until timeout':[7,27],
'Redirected until not found':[0,0], 'Redirected until error':[0,0], 'Redirected until found':[22084,13620]}
cc3_9 = pd.DataFrame(data=d3_9, index=['old', 'new'])
cc3_9
# Out:
#      not found  found (not redirected)  error  timeout  \
# old       5226                    8999   4575     1004
# new       2951                    4606  12018      411
#
#      Redirected until timeout  Redirected until not found  \
# old                         7                           0
# new                        27                           0
#
#      Redirected until error  Redirected until found
# old                       0                   22084
# new                       0                   13620

# %%
ax = cc3_9.T.plot.barh(figsize=(10,10))
ax.set_xlabel('#entities')
ax.set_title('CC(3-9)')
for container in ax.containers:
    ax.bar_label(container)

# %%
d10 = {'not found': [6455, 1853], 'found (not redirected)': [4288,3819], 'error': [6259,13827], 'timeout':[2120,421], 'Redirected until timeout':[1684,22],
'Redirected until not found':[2,0], 'Redirected until error':[0,0], 'Redirected until found':[9093,7262]}
cc10 = pd.DataFrame(data=d10, index=['old', 'new'])
cc10
# Out:
#      not found  found (not redirected)  error  timeout  \
# old       6455                    4288   6259     2120
# new       1853                    3819  13827      421
#
#      Redirected until timeout  Redirected until not found  \
# old                      1684                           2
# new                        22                           0
#
#      Redirected until error  Redirected until found
# old                       0                    9093
# new                       0                    7262

# %%
ax = cc10.T.plot.barh(figsize=(10,10))
ax.set_xlabel('#entities')
ax.set_title('CC(>10)')
for container in ax.containers:
    ax.bar_label(container)

# %%
ax = df.T.plot.barh(figsize=(10,10))
ax.set_xlabel('Percentage')
for container in ax.containers:
    ax.bar_label(container)

# %%
x, y, hue = "results", "percentage", "Identity graphs"
hue_order = ["new", "old"]
g = sns.catplot(x=x, y=y, hue=hue, kind='bar', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Idries\Desktop\Thesis\scaling_identity_refinement\visualisation_cc_new_kg.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Idries/Desktop/Thesis/scaling_identity_refinement/visualisation_cc_new_kg.ipynb#ch0000006?line=0'>1</a> x, y, hue = "results", "percentage", "Identity graphs"
#       <a href='vscode-notebook-cell:/c%3A/Users/Idries/Desktop/Thesis/scaling_identity_refinement/visualisation_cc_new_kg.ipynb#ch0000006?line=1'>2</a> hue_order = ["new", "old"]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Idries/Desktop/Thesis/scaling_identity_refinement/visualisation_cc_new_kg.ipynb#ch0000006?line=2'>3</a> g = sns.catplot(x=x, y=y, hue=hue, kind='bar', data=df)
#
# File c:\Users\Idries\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\Idries\anaconda3\lib\site-packages\seaborn\categorical.py:3792, in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790 p = _CategoricalPlotter()
#    3791 p.require_numeric = plotter_class.require_numeric
# -> 3792 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793 if (
#    3794     order is not None
#    3795     or (sharex and p.orient == "v")
#    3796     or (sharey and p.orient == "h")
#    3797 ):
#    3798     # Sync categorical axis between facets to have the same categories
#    3799     order = p.group_names
#
# File c:\Users\Idries\anaconda3\lib\site-packages\seaborn\categorical.py:153, in _CategoricalPlotter.establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151     if isinstance(var, str):
#     152         err = "Could not interpret input '{}'".format(var)
# --> 153         raise ValueError(err)
#     155 # Figure out the plotting orientation
#     156 orient = infer_orient(
#     157     x, y, orient, require_numeric=self.require_numeric
#     158 )
#
# ValueError: Could not interpret input 'results'

# %%
cc = pd.read_csv("size_cc_2_nr_occurences.tsv", header=None, sep="\t")
cc.columns=["cc_size", "nr_of_occurences"]
cc
# Out:
#      cc_size  nr_of_occurences
# 0          2         103044989
# 1          3          15818139
# 2          4           5725065
# 3          5           2563488
# 4          6           1796183
# ..       ...               ...
# 666     2409                 1
# 667     5564                 1
# 668     9041                 1
# 669    24674                 1
# 670   218828                 1
#
# [671 rows x 2 columns]

# %%
cc.plot.scatter(x='cc_size', y='nr_of_occurences')
# Out:
# <AxesSubplot:xlabel='cc_size', ylabel='nr_of_occurences'>

# %%
cc.boxplot()
# Out:
# <AxesSubplot:>
